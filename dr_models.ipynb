# %%
#mount google drive so we can access our data files

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load dependencies
import matplotlib.pyplot as plt
import seaborn as sns


import tensorflow as tf
import keras
from keras import backend as K

from tensorflow.keras.models import Model
from keras.layers import Activation, GlobalAveragePooling2D, Dropout, Dense, Flatten, Conv2D, MaxPooling2D
from keras.models import Sequential

from keras.applications import VGG16
from keras.applications import DenseNet121
from keras.applications import ResNet50

from keras.preprocessing.image import ImageDataGenerator

import pandas as pd
import numpy as np
import os
os.chdir('/content/drive/My Drive/')

# %%
#load data from file
try:
    x_train = np.load("preprocessed_images/training.npy", mmap_mode=None, allow_pickle=False, fix_imports=True)
    x_validation = np.load("preprocessed_images/validation.npy",mmap_mode=None, allow_pickle=False, fix_imports=True)
    x_test = np.load("preprocessed_images/test.npy", mmap_mode = None,allow_pickle = False, fix_imports = True)
    print(x_train.shape)
    print(x_validation.shape)
    print(x_test.shape)
except:
    print("file not found")
# Out:
# (3112, 512, 512, 3)
# (550, 512, 512, 3)
# (1928, 512, 512, 3)

# %%
#get labels for training and validation data

train_labels = pd.read_csv('train_dataframe.csv')
train_labels = train_labels['diagnosis']

validation_labels = pd.read_csv('validation_dataframe.csv')
validation_labels = validation_labels['diagnosis']

print(train_labels.shape[0])
print(validation_labels.shape[0])
# Out:
# 3112
# 550

# %%
#encode labels using ordinal encoding
#For example, if the original category is 2, our ordinal encoded label is [1,1,1,0,0] (encoded with 1's up to index 2)
def encode(labels):
    binary_labels = pd.get_dummies(labels).values
    cumulative_labels = np.empty(binary_labels.shape, dtype=binary_labels.dtype)
    cumulative_labels[:, 4] = binary_labels[:, 4]

    for i in range(3, -1, -1):
         cumulative_labels[:, i] = np.logical_or(binary_labels[:, i], cumulative_labels[:, i+1])
    return cumulative_labels

#encode labels
encoded_train_labels = encode(train_labels)
encoded_validation_labels = encode(validation_labels)

# %%
#define AlexNet architecture
def AlexNet():
    model = Sequential(name='alexnet')
    model.add(Conv2D(96,(11,11),strides = (4,4), padding = 'valid', activation = 'relu', kernel_initializer = 'he_normal',input_shape = (512,512,3)))
    model.add(MaxPooling2D(pool_size = (3,3), strides = (2,2)))
    model.add(Conv2D(256, kernel_size = (5,5), padding = 'same', activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (3,3), strides = (2,2)))
    model.add(Conv2D(384, kernel_size = (3,3), padding = 'same', activation= 'relu'))
    model.add(Conv2D(384, kernel_size = (3,3), padding = 'same', activation = 'relu'))
    model.add(Conv2D(256, kernel_size = (3,3), padding = 'same', activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (3,3), strides = (2,2)))
    model.add(Flatten())
    model.add(Dense(9216, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2048, activation = 'relu'))
    model.add(Dense(5, activation = 'sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.00001), metrics=['accuracy'])
    return model

# %%
alex_net = AlexNet()
alex_net.summary()
# Out:
# Model: "alexnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 126, 126, 96)      34944
#
#  max_pooling2d_18 (MaxPooli  (None, 62, 62, 96)        0
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 62, 62, 256)       614656
#
#  max_pooling2d_19 (MaxPooli  (None, 30, 30, 256)       0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 30, 30, 384)       885120
#
#  conv2d_23 (Conv2D)          (None, 30, 30, 384)       1327488
#
#  conv2d_24 (Conv2D)          (None, 30, 30, 256)       884992
#
#  max_pooling2d_20 (MaxPooli  (None, 14, 14, 256)       0
#  ng2D)
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_26 (Dense)            (None, 9216)              462431232
#
#  dropout_9 (Dropout)         (None, 9216)              0
#
#  dense_27 (Dense)            (None, 4096)              37752832
#
#  dropout_10 (Dropout)        (None, 4096)              0
#
#  dense_28 (Dense)            (None, 2048)              8390656
#
#  dense_29 (Dense)            (None, 5)                 10245
#
# =================================================================
# Total params: 512332165 (1.91 GB)
# Trainable params: 512332165 (1.91 GB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#train AlexNet model
alex_net = AlexNet()
history = alex_net.fit(x_train, encoded_train_labels, epochs = 10, batch_size = 8, verbose = 2, validation_data=(x_validation, encoded_validation_labels))
# Out:
# Epoch 1/10
# 389/389 - 15s - loss: 2.0071 - accuracy: 0.9553 - val_loss: 0.2849 - val_accuracy: 1.0000 - 15s/epoch - 40ms/step
# Epoch 2/10
# 389/389 - 12s - loss: 0.3112 - accuracy: 0.9820 - val_loss: 0.2647 - val_accuracy: 0.9545 - 12s/epoch - 32ms/step
# Epoch 3/10
# 389/389 - 12s - loss: 0.2760 - accuracy: 0.9839 - val_loss: 0.2604 - val_accuracy: 0.9818 - 12s/epoch - 32ms/step
# Epoch 4/10
# 389/389 - 12s - loss: 0.2619 - accuracy: 0.9843 - val_loss: 0.2532 - val_accuracy: 1.0000 - 12s/epoch - 32ms/step
# Epoch 5/10
# 389/389 - 12s - loss: 0.2557 - accuracy: 0.9830 - val_loss: 0.2510 - val_accuracy: 0.9982 - 12s/epoch - 32ms/step
# Epoch 6/10
# 389/389 - 12s - loss: 0.2399 - accuracy: 0.9833 - val_loss: 0.2453 - val_accuracy: 1.0000 - 12s/epoch - 32ms/step
# Epoch 7/10
# 389/389 - 12s - loss: 0.2279 - accuracy: 0.9836 - val_loss: 0.2409 - val_accuracy: 1.0000 - 12s/epoch - 32ms/step
# Epoch 8/10
# 389/389 - 12s - loss: 0.2324 - accuracy: 0.9820 - val_loss: 0.2433 - val_accuracy: 1.0000 - 12s/epoch - 32ms/step
# Epoch 9/10
# 389/389 - 12s - loss: 0.2260 - accuracy: 0.9904 - val_loss: 0.2387 - val_accuracy: 0.9855 - 12s/epoch - 32ms/step
# Epoch 10/10
# 389/389 - 12s - loss: 0.2169 - accuracy: 0.9733 - val_loss: 0.2546 - val_accuracy: 0.8218 - 12s/epoch - 32ms/step

# %%
#evaluate AlexNet
loss, acc = alex_net.evaluate(x_validation, encoded_validation_labels)
y_pred = alex_net.predict(x_validation)
print("Accuracy after training for 10 epochs: ", acc)
# Out:
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2546 - accuracy: 0.8218
# 18/18 [==============================] - 0s 15ms/step
# Accuracy after training for 10 epochs:  0.8218181729316711

# %%
#add custom layers to pretrained architectures
def create_gap_layer():
    return GlobalAveragePooling2D()

def create_dropout_layer(value = 0.5):
    return Dropout(value)

def create_dense_layer():
    return Dense(5, activation='sigmoid')

global_average_pooling_layer = create_gap_layer()
dropout_layer = create_dropout_layer()
dense_layer = create_dense_layer()

# %%
#define vgg16 architecture
def vgg_16(top_6 = False):
    vgg = VGG16(weights = 'imagenet', include_top = False, input_shape = (512,512,3))
    if not top_6:
        for layer in vgg.layers:
            layer.trainable = False
    else:
         for layer in vgg.layers[:13]:
            layer.trainable=False
    x = global_average_pooling_layer(vgg.layers[-1].output)
    x = dropout_layer(x)
    output = dense_layer(x)
    model = Model(vgg.layers[0].input,output)
    model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.00005), metrics=['accuracy'])
    return model

# %%
vgg16 = vgg_16(True)
vgg16.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 512, 512, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 512, 512, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 512, 512, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 256, 256, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 256, 256, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 256, 256, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 128, 128, 128)     0
#
#  block3_conv1 (Conv2D)       (None, 128, 128, 256)     295168
#
#  block3_conv2 (Conv2D)       (None, 128, 128, 256)     590080
#
#  block3_conv3 (Conv2D)       (None, 128, 128, 256)     590080
#
#  block3_pool (MaxPooling2D)  (None, 64, 64, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 64, 64, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 32, 32, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  global_average_pooling2d_1  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 14717253 (56.14 MB)
# Trainable params: 9441797 (36.02 MB)
# Non-trainable params: 5275456 (20.12 MB)
# _________________________________________________________________

# %%
#perform horizontal flipping, vertical flipping, rotation, and zoom -- helps prevent overfitting due to small size of our dataset
generator = ImageDataGenerator(horizontal_flip=True,vertical_flip=True,rotation_range=180,zoom_range = 0.2)
vgg16 = vgg_16(top_6 = True)
history = vgg16.fit(
                   generator.flow(x_train, encoded_train_labels, batch_size=12),
                    steps_per_epoch=len(x_train) / 12,
                    epochs=10,
                    initial_epoch=0,
                    verbose=1,
                    validation_data=(x_validation, encoded_validation_labels),
                    validation_steps=len(x_validation) / 12)
# Out:
# Epoch 1/10
# 260/259 [==============================] - ETA: 0s - loss: 0.2582 - accuracy: 0.9499Validation data not provided.
# 259/259 [==============================] - 180s 686ms/step - loss: 0.2582 - accuracy: 0.9499 - val_loss: 0.1861 - val_accuracy: 0.9964
# Epoch 2/10
# 260/259 [==============================] - ETA: 0s - loss: 0.1769 - accuracy: 0.8670Validation data not provided.
# 259/259 [==============================] - 178s 686ms/step - loss: 0.1769 - accuracy: 0.8670 - val_loss: 0.1728 - val_accuracy: 0.6727
# Epoch 3/10
# 260/259 [==============================] - ETA: 0s - loss: 0.1692 - accuracy: 0.7815Validation data not provided.
# 259/259 [==============================] - 178s 687ms/step - loss: 0.1692 - accuracy: 0.7815 - val_loss: 0.1399 - val_accuracy: 0.8073
# Epoch 4/10
# 260/259 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.7667Validation data not provided.
# 259/259 [==============================] - 178s 684ms/step - loss: 0.1483 - accuracy: 0.7667 - val_loss: 0.1559 - val_accuracy: 0.8273
# Epoch 5/10
# 260/259 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.7834Validation data not provided.
# 259/259 [==============================] - 178s 685ms/step - loss: 0.1409 - accuracy: 0.7834 - val_loss: 0.1362 - val_accuracy: 0.8727
# Epoch 6/10
# 260/259 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.7950Validation data not provided.
# 259/259 [==============================] - 178s 688ms/step - loss: 0.1365 - accuracy: 0.7950 - val_loss: 0.1398 - val_accuracy: 0.7273
# Epoch 7/10
# 260/259 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.7892Validation data not provided.
# 259/259 [==============================] - 178s 686ms/step - loss: 0.1304 - accuracy: 0.7892 - val_loss: 0.1269 - val_accuracy: 0.8164
# Epoch 8/10
# 260/259 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.8133Validation data not provided.
# 259/259 [==============================] - 178s 685ms/step - loss: 0.1336 - accuracy: 0.8133 - val_loss: 0.1381 - val_accuracy: 0.9000
# Epoch 9/10
# 260/259 [==============================] - ETA: 0s - loss: 0.1278 - accuracy: 0.8448Validation data not provided.
# 259/259 [==============================] - 178s 687ms/step - loss: 0.1278 - accuracy: 0.8448 - val_loss: 0.1288 - val_accuracy: 0.8545
# Epoch 10/10
# 260/259 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.8342Validation data not provided.
# 259/259 [==============================] - 178s 685ms/step - loss: 0.1258 - accuracy: 0.8342 - val_loss: 0.1894 - val_accuracy: 0.9182

# %%
#evaluate vgg16
test_loss, test_acc = vgg16.evaluate(x_validation,encoded_validation_labels)
y_pred = vgg16.predict(x_validation)
print("Test accuracy after training for 10 epochs: ", test_acc)
# Out:
# 18/18 [==============================] - 7s 157ms/step - loss: 0.1894 - accuracy: 0.9182
# 18/18 [==============================] - 2s 84ms/step
# Test accuracy after training for 10 epochs:  0.918181836605072

# %%
global_average_pooling_layer = create_gap_layer()
dropout_layer = create_dropout_layer()
dense_layer = create_dense_layer()

# %%
#define model architecture for Densenet121 -- uses pretrained model on imagenet dataset
def DenseNet():
    densenet = DenseNet121(weights='imagenet', include_top=False, input_shape=(512,512,3))
    x = global_average_pooling_layer(densenet.layers[-1].output)
    x = dropout_layer(x)
    output = dense_layer(x)
    model = Model(densenet.layers[0].input,output)
    model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.00005), metrics=['accuracy'])
    return model

# %%
densenet = DenseNet()
densenet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 518, 518, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 256, 256, 64)         9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 256, 256, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 256, 256, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 258, 258, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 128, 128, 64)         0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 128, 128, 64)         256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 128, 128, 128)        8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 128, 128, 128)        512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 128, 128, 128)        0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 128, 128, 32)         36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 128, 128, 96)         0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 128, 128, 96)         384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 128, 128, 96)         0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 128, 128, 128)        12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 128, 128, 128)        512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 128, 128, 128)        0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 128, 128, 32)         36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 128, 128, 128)        0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 128, 128, 128)        512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 128, 128, 128)        0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 128, 128, 128)        16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 128, 128, 128)        512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 128, 128, 128)        0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 128, 128, 32)         36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 128, 128, 160)        0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 128, 128, 160)        640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 128, 128, 160)        0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 128, 128, 128)        20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 128, 128, 128)        512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 128, 128, 128)        0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 128, 128, 32)         36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 128, 128, 192)        0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 128, 128, 192)        768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 128, 128, 192)        0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 128, 128, 128)        24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 128, 128, 128)        512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 128, 128, 128)        0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 128, 128, 32)         36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 128, 128, 224)        0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 128, 128, 224)        896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 128, 128, 224)        0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 128, 128, 128)        28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 128, 128, 128)        512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 128, 128, 128)        0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 128, 128, 32)         36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 128, 128, 256)        0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 128, 128, 256)        1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 128, 128, 256)        0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 128, 128, 128)        32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 64, 64, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 64, 64, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 64, 64, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 64, 64, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 64, 64, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 64, 64, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 64, 64, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 64, 64, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 64, 64, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 64, 64, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 64, 64, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 64, 64, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 64, 64, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 64, 64, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 64, 64, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 64, 64, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 64, 64, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 64, 64, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 64, 64, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 64, 64, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 64, 64, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 64, 64, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 64, 64, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 64, 64, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 64, 64, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 64, 64, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 64, 64, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 64, 64, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 64, 64, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 64, 64, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 64, 64, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 64, 64, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 64, 64, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 64, 64, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 64, 64, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 64, 64, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 64, 64, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 64, 64, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 64, 64, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 64, 64, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 64, 64, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 64, 64, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 64, 64, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 64, 64, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 64, 64, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 64, 64, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 64, 64, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 64, 64, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 64, 64, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 64, 64, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 64, 64, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 64, 64, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 64, 64, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 64, 64, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 64, 64, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 64, 64, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 64, 64, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 64, 64, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 64, 64, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 32, 32, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 32, 32, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 32, 32, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 32, 32, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 32, 32, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 32, 32, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 32, 32, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 32, 32, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 32, 32, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 32, 32, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 32, 32, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 32, 32, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 32, 32, 352)          1408      ['conv4_block3_concat[0][0]']
# ...
#  ormalization)
#
#  conv5_block10_0_relu (Acti  (None, 16, 16, 800)          0         ['conv5_block10_0_bn[0][0]']
#  vation)
#
#  conv5_block10_1_conv (Conv  (None, 16, 16, 128)          102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 16, 16, 128)          512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 16, 16, 128)          0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 16, 16, 32)           36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 16, 16, 832)          0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 16, 16, 832)          3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 16, 16, 832)          0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 16, 16, 128)          106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 16, 16, 128)          512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 16, 16, 128)          0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 16, 16, 32)           36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 16, 16, 864)          0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 16, 16, 864)          3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 16, 16, 864)          0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 16, 16, 128)          110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 16, 16, 128)          512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 16, 16, 128)          0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 16, 16, 32)           36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 16, 16, 896)          0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 16, 16, 896)          3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 16, 16, 896)          0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 16, 16, 128)          114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 16, 16, 128)          512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 16, 16, 128)          0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 16, 16, 32)           36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 16, 16, 928)          0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 16, 16, 928)          3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 16, 16, 928)          0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 16, 16, 128)          118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 16, 16, 128)          512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 16, 16, 128)          0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 16, 16, 32)           36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 16, 16, 960)          0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 16, 16, 960)          3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 16, 16, 960)          0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 16, 16, 128)          122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 16, 16, 128)          512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 16, 16, 128)          0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 16, 16, 32)           36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 16, 16, 992)          0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 16, 16, 992)          3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 16, 16, 992)          0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 16, 16, 128)          126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 16, 16, 128)          512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 16, 16, 128)          0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 16, 16, 32)           36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 16, 16, 1024)         0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 16, 16, 1024)         4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 16, 16, 1024)         0         ['bn[0][0]']
#
#  global_average_pooling2d_2  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 1024)                 0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_8 (Dense)             (None, 5)                    5125      ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 7042629 (26.87 MB)
# Trainable params: 6958981 (26.55 MB)
# Non-trainable params: 83648 (326.75 KB)
# __________________________________________________________________________________________________

# %%
#train densenet
generator = ImageDataGenerator(horizontal_flip=True,vertical_flip=True,rotation_range=180,zoom_range = 0.2)
densenet = DenseNet()
history = densenet.fit(
                    generator.flow(x_train, encoded_train_labels, batch_size=8),
                    steps_per_epoch=len(x_train) / 8,
                    epochs=10,
                    initial_epoch=0,
                    verbose=1,
                    validation_data=(x_validation, encoded_validation_labels),
                    validation_steps=len(x_validation) / 8)
# Out:
# Epoch 1/10
# 389/389 [==============================] - 236s 448ms/step - loss: 0.3043 - accuracy: 0.6099 - val_loss: 0.1464 - val_accuracy: 0.6855
# Epoch 2/10
# 389/389 [==============================] - 171s 440ms/step - loss: 0.1750 - accuracy: 0.7085 - val_loss: 0.1200 - val_accuracy: 0.7164
# Epoch 3/10
# 389/389 [==============================] - 173s 446ms/step - loss: 0.1450 - accuracy: 0.7561 - val_loss: 0.1279 - val_accuracy: 0.7036
# Epoch 4/10
# 389/389 [==============================] - 173s 443ms/step - loss: 0.1349 - accuracy: 0.7381 - val_loss: 0.1144 - val_accuracy: 0.6473
# Epoch 5/10
# 389/389 [==============================] - 173s 445ms/step - loss: 0.1369 - accuracy: 0.7683 - val_loss: 0.1241 - val_accuracy: 0.6782
# Epoch 6/10
# 389/389 [==============================] - 172s 441ms/step - loss: 0.1245 - accuracy: 0.7792 - val_loss: 0.1206 - val_accuracy: 0.6582
# Epoch 7/10
# 389/389 [==============================] - 173s 444ms/step - loss: 0.1195 - accuracy: 0.7792 - val_loss: 0.1104 - val_accuracy: 0.8382
# Epoch 8/10
# 389/389 [==============================] - 172s 441ms/step - loss: 0.1165 - accuracy: 0.8165 - val_loss: 0.1172 - val_accuracy: 0.8309
# Epoch 9/10
# 389/389 [==============================] - 176s 452ms/step - loss: 0.1150 - accuracy: 0.8149 - val_loss: 0.1046 - val_accuracy: 0.8091
# Epoch 10/10
# 389/389 [==============================] - 173s 445ms/step - loss: 0.1064 - accuracy: 0.7992 - val_loss: 0.1861 - val_accuracy: 0.6691

# %%
#evaluate densenet
test_loss, test_acc = densenet.evaluate(x_validation,encoded_validation_labels)
y_pred = densenet.predict(x_validation)
print("Accuracy after training for 10 epochs: ", test_acc)
# Out:
# 18/18 [==============================] - 2s 85ms/step - loss: 0.1861 - accuracy: 0.6691
# 18/18 [==============================] - 3s 86ms/step
# Accuracy after training for 10 epochs:  0.6690909266471863

# %%
global_average_pooling_layer = create_gap_layer()
dropout_layer = create_dropout_layer()
dense_layer = create_dense_layer()

# %%
#define architecture for ResNet50 -- uses pretrained model on imagenet dataset
def ResNet_50():
    resnet = ResNet50(weights='imagenet',include_top=False,layers=keras.layers,input_shape=(512,512,3))
    x = global_average_pooling_layer(resnet.layers[-1].output)
    x = dropout_layer(x)
    output = dense_layer(x)
    model = Model(resnet.layers[0].input,output)
    model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.00005), metrics=['accuracy'])
    return model

# %%
resnet = ResNet_50()
resnet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 518, 518, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 256, 256, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 256, 256, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 256, 256, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 258, 258, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 128, 128, 64)         0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 128, 128, 64)         4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 128, 128, 256)        16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 128, 128, 256)        0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 128, 128, 256)        0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 128, 128, 64)         16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 128, 128, 256)        0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 128, 128, 256)        0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 128, 128, 64)         16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 128, 128, 256)        0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 128, 128, 256)        0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 64, 64, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 64, 64, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 64, 64, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 64, 64, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 64, 64, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 64, 64, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 64, 64, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 64, 64, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 64, 64, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 64, 64, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 32, 32, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 32, 32, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 16, 16, 512)          524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 16, 16, 2048)         2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 16, 16, 512)          1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 16, 16, 512)          1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block3_add[0][0]']
#  on)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_1 (Dense)             (None, 5)                    10245     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 23597957 (90.02 MB)
# Trainable params: 23544837 (89.82 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
#train ResNet50
generator = ImageDataGenerator(horizontal_flip=True,vertical_flip=True,rotation_range=180,zoom_range = 0.2)
history = resnet.fit(
                   generator.flow(x_train, encoded_train_labels, batch_size = 8),
                    steps_per_epoch=len(x_train) / 8,
                    epochs=10,
                    initial_epoch=0,
                    verbose=1,
                    validation_data=(x_validation, encoded_validation_labels),
                    validation_steps=len(x_validation) / 8)
# Out:
# Epoch 1/10
# 389/389 [==============================] - 214s 452ms/step - loss: 0.2246 - accuracy: 0.8191 - val_loss: 0.1684 - val_accuracy: 0.6709
# Epoch 2/10
# 389/389 [==============================] - 175s 449ms/step - loss: 0.1594 - accuracy: 0.8262 - val_loss: 0.2022 - val_accuracy: 0.7182
# Epoch 3/10
# 389/389 [==============================] - 173s 445ms/step - loss: 0.1382 - accuracy: 0.7706 - val_loss: 0.1125 - val_accuracy: 0.6691
# Epoch 4/10
# 389/389 [==============================] - 176s 452ms/step - loss: 0.1269 - accuracy: 0.7956 - val_loss: 0.1247 - val_accuracy: 0.7545
# Epoch 5/10
# 389/389 [==============================] - 176s 452ms/step - loss: 0.1168 - accuracy: 0.7918 - val_loss: 0.1145 - val_accuracy: 0.7636
# Epoch 6/10
# 389/389 [==============================] - 176s 452ms/step - loss: 0.1094 - accuracy: 0.7773 - val_loss: 0.1092 - val_accuracy: 0.7018
# Epoch 7/10
# 389/389 [==============================] - 178s 458ms/step - loss: 0.1068 - accuracy: 0.7905 - val_loss: 0.1774 - val_accuracy: 0.7182
# Epoch 8/10
# 389/389 [==============================] - 177s 454ms/step - loss: 0.1059 - accuracy: 0.7950 - val_loss: 0.1508 - val_accuracy: 0.8818
# Epoch 9/10
# 389/389 [==============================] - 177s 454ms/step - loss: 0.1007 - accuracy: 0.7979 - val_loss: 0.1310 - val_accuracy: 0.8600
# Epoch 10/10
# 389/389 [==============================] - 176s 451ms/step - loss: 0.0949 - accuracy: 0.8403 - val_loss: 0.1326 - val_accuracy: 0.7964

# %%
#evaluate ResNet50
loss, acc = resnet.evaluate(x_validation,encoded_validation_labels)
y_pred = resnet.predict(x_validation)
print("Accuracy after training for 10 epochs: ", acc)
# Out:
# 18/18 [==============================] - 4s 78ms/step - loss: 0.1326 - accuracy: 0.7964
# 18/18 [==============================] - 2s 74ms/step
# Accuracy after training for 10 epochs:  0.7963636517524719
